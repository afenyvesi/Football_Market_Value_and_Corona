# %% [markdown]
# # Import Packages

# %%
import requests
from bs4 import BeautifulSoup
import json
from tqdm import tqdm_notebook as tqdm
import pandas as pd
import numpy as np
import random
import time
import js2xml
import re

# %% [markdown]
# # Scraping setup

# %% [markdown]
# ## Rotating headers

# %%
user_agent_list = [
   #Chrome
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.113 Safari/537.36',
    'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.90 Safari/537.36',
    'Mozilla/5.0 (Windows NT 5.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.90 Safari/537.36',
    'Mozilla/5.0 (Windows NT 6.2; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.90 Safari/537.36',
    'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36',
    'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.113 Safari/537.36',
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/57.0.2987.133 Safari/537.36',
    'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/57.0.2987.133 Safari/537.36',
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.87 Safari/537.36',
    'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.87 Safari/537.36',
    #Firefox
    'Mozilla/4.0 (compatible; MSIE 9.0; Windows NT 6.1)',
    'Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7.0; rv:11.0) like Gecko',
    'Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.1; WOW64; Trident/5.0)',
    'Mozilla/5.0 (Windows NT 6.1; Trident/7.0; rv:11.0) like Gecko',
    'Mozilla/5.0 (Windows NT 6.2; WOW64; Trident/7.0; rv:11.0) like Gecko',
    'Mozilla/5.0 (Windows NT 10.0; WOW64; Trident/7.0; rv:11.0) like Gecko',
    'Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.0; Trident/5.0)',
    'Mozilla/5.0 (Windows NT 6.3; WOW64; Trident/7.0; rv:11.0) like Gecko',
    'Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.1; Trident/5.0)',
    'Mozilla/5.0 (Windows NT 6.1; Win64; x64; Trident/7.0; rv:11.0) like Gecko',
    'Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.1; WOW64; Trident/6.0)',
    'Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.1; Trident/6.0)',
    'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0; .NET CLR 2.0.50727; .NET CLR 3.0.4506.2152; .NET CLR 3.5.30729)'
]

# %% [markdown]
# ## Delays

# %%
delays = np.linspace(10,15,6)
#delays = np.linspace(20,40,21)
#delays = np.linspace(3,10,7)
#delays = np.linspace(15,35,21)

# %% [markdown]
# ## Scraping functions

# %%
def get_soup(url):
    '''
    Tries to get the html code of a web page, returns Failure if it is unsuccessful.
    '''
    
    # Choosing a random header from the previously given list
    header = {'User-Agent' : random.choice(user_agent_list)} 

    # Delaying the request for a random number of seconds from the range given in delays
    time.sleep(random.choice(delays))
    
    # Try to reach the page and get its content. Checks for the status code.
    try:
        r = requests.get(url, 
                         headers = header)
        if r.status_code == 200:
            soup = BeautifulSoup(r.content,'html.parser')
            siker = True
        else:
            print('Bad status code! STOPPED')
            siker=False
            soup = ''
    except:
        soup=''
        siker=False
    
    # The function returns a boolean (success), and the html text of the webpage
    return siker,soup

# %% [markdown]
# ## Base URLs

# %%
BASEURL = 'https://www.transfermarkt.co.uk'

# %%
# English Premier League
epl = 'https://www.transfermarkt.co.uk/premier-league/startseite/wettbewerb/GB1'
# Spanish La Liga
laliga = 'https://www.transfermarkt.co.uk/laliga/startseite/wettbewerb/ES1'
# Italian Serie A
seriea = 'https://www.transfermarkt.co.uk/serie-a/startseite/wettbewerb/IT1'
# German Bundesliga
bliga = 'https://www.transfermarkt.co.uk/bundesliga/startseite/wettbewerb/L1'
# French Ligue 1
ligue1 = 'https://www.transfermarkt.co.uk/ligue-1/startseite/wettbewerb/FR1'

leagues = [epl, laliga, seriea, bliga, ligue1]

# %% [markdown]
# # Scraping

# %% [markdown]
# ## Getting URLs to squad lists

# %% [markdown]
# We want to scrape the information of the palyers of Europe's top 5 leagues. (The English, Spanish, German, Italian and French football leagues.)
#
# For this we need a list of URLs for these players.
#
# For the list of URLs of these players we need a list of URLs for the clubs.

# %%
siker,soup = get_soup(epl)

# %%
def get_league_soups(leagues):
    soups = []
    for url in leagues:
        siker,soup = get_soup(url)
        soups.append(soup)
    return soups

def find_teamnames_urls(soups):
    teams = {'name' : [], 'url' : []}
    for soup in soups:
        box = soup.find_all('td', {'class' : 'hauptlink no-border-links show-for-small show-for-pad'})
        for team in box:
            teams['name'].append(team.find('a').text)
            teams['url'].append(BASEURL + team.find('a')['href'])
    return(teams)

def create_teamsdf(leagues):
    teamsdf = pd.DataFrame(find_teamnames_urls(get_league_soups(leagues)))
    teamsdf['squadlist'] = ['/'.join(url.split('/')[0:4] + ['kader'] + url.split('/')[5:] + ['plus/1']) for url in teamsdf['url']]
    return teamsdf

# %%
teamsdf = create_teamsdf(leagues)
teamsdf
# Out:
#                name                                                url  \
# 0          Man City  https://www.transfermarkt.co.uk/manchester-cit...
# 1         Liverpool  https://www.transfermarkt.co.uk/fc-liverpool/s...
# 2             Spurs  https://www.transfermarkt.co.uk/tottenham-hots...
# 3           Chelsea  https://www.transfermarkt.co.uk/fc-chelsea/sta...
# 4           Man Utd  https://www.transfermarkt.co.uk/manchester-uni...
# ..              ...                                                ...
# 93        SC Amiens  https://www.transfermarkt.co.uk/sc-amiens/star...
# 94          FC Metz  https://www.transfermarkt.co.uk/fc-metz/starts...
# 95   Stade Brest 29  https://www.transfermarkt.co.uk/stade-brest-29...
# 96  Nîmes Olympique  https://www.transfermarkt.co.uk/olympique-nime...
# 97            Dijon  https://www.transfermarkt.co.uk/fco-dijon/star...
#
#                                             squadlist
# 0   https://www.transfermarkt.co.uk/manchester-cit...
# 1   https://www.transfermarkt.co.uk/fc-liverpool/k...
# 2   https://www.transfermarkt.co.uk/tottenham-hots...
# 3   https://www.transfermarkt.co.uk/fc-chelsea/kad...
# 4   https://www.transfermarkt.co.uk/manchester-uni...
# ..                                                ...
# 93  https://www.transfermarkt.co.uk/sc-amiens/kade...
# 94  https://www.transfermarkt.co.uk/fc-metz/kader/...
# 95  https://www.transfermarkt.co.uk/stade-brest-29...
# 96  https://www.transfermarkt.co.uk/olympique-nime...
# 97  https://www.transfermarkt.co.uk/fco-dijon/kade...
#
# [98 rows x 3 columns]

# %% [markdown]
# ## Getting the squad data

# %% [markdown]
# Now we will collect the current squads of the 98 teams, and some basic information about the players.
#
# An important part of this task is to collect the players URLs, which will let us collect the market values and performance statisctics on a player level.

# %%
def get_all_squads(teamsdf):
    squads = []
    for squadurl in teamsdf['squadlist']:
        squad = []
        siker,soup = get_soup(squadurl)
        players = soup.find_all('tr', {'class' : 'odd'}) + soup.find_all('tr', {'class' : 'even'})
        for player in players:
            playerinfo = {}
            infos = player.find_all('td', {'class' : 'zentriert'})
            try:
                playerinfo['kit'] = player.find('div', {'class' : 'rn_nummer'}).text
            except:
                playerinfo['kit'] = ''
            try:
                playerinfo['name'] = player.find('a', {'class' : 'spielprofil_tooltip'}).text
            except:
                playerinfo['name'] = ''
            try:
                playerinfo['genposition'] = infos[0]['title']
            except:
                playerinfo['genposition'] = ''
            try:
                playerinfo['specposition'] = player.find('table', {'class' : 'inline-table'}).find_all('tr')[1].text
            except:
                playerinfo['specposition'] = ''
            try:
                playerinfo['dateofbirth'] = infos[1].text
            except:
                playerinfo['dateofbirth'] = ''
            try:
                playerinfo['nationality'] = infos[2].find('img', {'class' : 'flaggenrahmen'})['title']
            except:
                playerinfo['nationality'] = ''
            try:
                playerinfo['height'] = infos[3].text
            except:
                playerinfo['height'] = ''
            try:
                playerinfo['foot'] = infos[4].text
            except:
                playerinfo['foot'] = ''
            try:
                playerinfo['joined'] = infos[5].text
            except:
                playerinfo['joined'] = ''
            try:
                playerinfo['lastclub'] = infos[6].find('img')['alt']
            except:
                playerinfo['lastclub'] = ''
            try:
                playerinfo['contract'] = infos[7].text
            except:
                playerinfo['contract'] = ''
            try:
                playerinfo['playerurl'] = BASEURL + player.find('a', {'class' : 'spielprofil_tooltip'})['href']
            except:
                playerinfo['playerurl'] = ''
            squad.append(playerinfo)
        squads.append(squad)
        print(len(squads), ' teams done!')
    teamsdf['squaddata'] = squads
    return teamsdf

# %%
new_df2 = get_all_squads(teamsdf)
new_df2

# %%
new_df2.to_csv('teams_dataframe_status0513.csv', sep = ';', encoding = 'utf-8')

# %%
new_df2.head()
# Out:
#         name                                                url  \
# 0   Man City  https://www.transfermarkt.co.uk/manchester-cit...
# 1  Liverpool  https://www.transfermarkt.co.uk/fc-liverpool/s...
# 2      Spurs  https://www.transfermarkt.co.uk/tottenham-hots...
# 3    Chelsea  https://www.transfermarkt.co.uk/fc-chelsea/sta...
# 4    Man Utd  https://www.transfermarkt.co.uk/manchester-uni...
#
#                                            squadlist  \
# 0  https://www.transfermarkt.co.uk/manchester-cit...
# 1  https://www.transfermarkt.co.uk/fc-liverpool/k...
# 2  https://www.transfermarkt.co.uk/tottenham-hots...
# 3  https://www.transfermarkt.co.uk/fc-chelsea/kad...
# 4  https://www.transfermarkt.co.uk/manchester-uni...
#
#                                            squaddata
# 0  [{'kit': '31', 'name': 'Ederson', 'genposition...
# 1  [{'kit': '1', 'name': 'Alisson', 'genposition'...
# 2  [{'kit': '1', 'name': 'Hugo Lloris', 'genposit...
# 3  [{'kit': '1', 'name': 'Kepa', 'genposition': '...
# 4  [{'kit': '1', 'name': 'David de Gea', 'genposi...

# %%
pd.DataFrame(new_df2['squaddata'][80]).head(5)
# Out:
#   kit               name genposition specposition        dateofbirth  \
# 0  40   Benjamin Lecomte  Goalkeeper   Goalkeeper  Apr 26, 1991 (29)
# 1  40    Loïc Badiashile  Goalkeeper   Goalkeeper   Feb 5, 1998 (22)
# 2  16     Diego Benaglio  Goalkeeper   Goalkeeper   Sep 8, 1983 (36)
# 3   3  Guillermo Maripán    Defender  Centre-Back   May 6, 1994 (26)
# 4   5           Jemerson    Defender  Centre-Back  Aug 24, 1992 (27)
#
#    nationality  height   foot        joined                lastclub  \
# 0       France  1,86 m   left  Jul 15, 2019         HSC Montpellier
# 1       France  1,86 m  right   Jul 1, 2016           AS Monaco U19
# 2  Switzerland  1,94 m  right   Jul 1, 2017           VfL Wolfsburg
# 3        Chile  1,93 m  right  Aug 24, 2019        Deportivo Alavés
# 4       Brazil  1,84 m  right  Jan 31, 2016  Clube Atlético Mineiro
#
#      contract                                          playerurl
# 0  30.06.2024  https://www.transfermarkt.co.uk/benjamin-lecom...
# 1  30.06.2021  https://www.transfermarkt.co.uk/loic-badiashil...
# 2  30.06.2020  https://www.transfermarkt.co.uk/diego-benaglio...
# 3  30.06.2024  https://www.transfermarkt.co.uk/guillermo-mari...
# 4  30.06.2020  https://www.transfermarkt.co.uk/jemerson/profi...

# %% [markdown]
# ## Player Data

# %% [markdown]
# Now we have the squad lists of the clubs. We will have to collect
# - Performance stats
# - International record
# - Personal Awards
#
# for each player.

# %% [markdown]
# How many players are there in our dataset?

# %%
playnum = 0
for squad in new_df2['squaddata']:
    playnum += len(squad)
    
print('The number of players in the dataset is: ', playnum)
print('Scraping this would take ', 10 * playnum / 60, ' - ', 15 * playnum / 60, ' minutes.')
# Out:
# The number of players in the dataset is:  2575
# Scraping this would take  429.1666666666667  -  643.75  minutes.

# %% [markdown]
# ### Market value data

# %%
def get_market_values(playerurl):
    '''
    Converts the player profile URL to the player value URL,
    and scrapes all the known market values of the player, and returns as a dictionary
    '''
    url = '/'.join(playerurl.split('/')[0:4] + ['marktwertverlauf'] + playerurl.split('/')[5:])
    siker, soup = get_soup(url)
    try:
        script = soup.find("script", text=re.compile("Highcharts.Chart")).text
        parsed = js2xml.parse(script)
        values = [d.xpath(".//array/object/property[@name='y']/number/@value") for d in parsed.xpath("//property[@name='data']")][3]
        dates = [d.xpath(".//array/object/property[@name='datum_mw']/string/text()") for d in parsed.xpath("//property[@name='data']")][3]
    except:
        values = ''
        dates = ''
    return {'date' : dates, 'market_value' : values}

# %%
pd.DataFrame(get_market_values('https://www.transfermarkt.co.uk/ansu-fati/profil/spieler/466810'))
# Out:
#            date market_value
# 0  Sep 10, 2019     22500000
# 1  Dec 20, 2019     36000000
# 2   Apr 8, 2020     32400000

# %% [markdown]
# ### Player Performance Data

# %%
def get_player_stats(playerurl):
    url = '/'.join(playerurl.split('/')[0:4] + ['leistungsdatendetails/spieler'] + [playerurl.split('/')[6]] + ['saison//verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1'])
    siker, soup = get_soup(url)
    try:
        statrows = soup.find_all('tr', {'class' : 'odd'}) + soup.find_all('tr', {'class' : 'even'})
        playerstats = [] # Every player will have a list of dictionaries for his stats
        for row in statrows:
            playerstatrow = {}
            infos1 = row.find_all('td', {'class' : 'zentriert'})
            try:
                playerstatrow['season'] = infos1[0].text
            except:
                playerstatrow['season'] = ''
            try:
                playerstatrow['competition'] = row.find('td', {'class' : 'hauptlink no-border-links'}).text
            except:
                playerstatrow['competition'] = ''
            try:
                playerstatrow['in_squad'] = infos1[2].text
            except:
                playerstatrow['in_squad'] = ''
            try:
                playerstatrow['appearances'] = infos1[3].text
            except:
                playerstatrow['appearances'] = ''
            try:
                playerstatrow['pointspermatch'] = infos1[4].text
            except:
                playerstatrow['pointspermatch'] = ''
            try:
                playerstatrow['goals'] = infos1[5].text
            except:
                playerstatrow['goals'] = ''
            try:
                playerstatrow['assists'] = infos1[6].text
            except:
                playerstatrow['assists'] = ''
            try:
                playerstatrow['owngoals'] = infos1[7].text
            except:
                playerstatrow['owngoals'] = ''
            try:
                playerstatrow['sub_on'] = infos1[8].text
            except:
                playerstatrow['sub_on'] = ''
            try:
                playerstatrow['sub_off'] = infos1[9].text
            except:
                playerstatrow['sub_off'] = ''
            try:
                playerstatrow['yellow'] = infos1[10].text
            except:
                playerstatrow['yellow'] = ''
            try:
                playerstatrow['secondyellow'] = infos1[11].text
            except:
                playerstatrow['secondyellow'] = ''
            try:
                playerstatrow['red'] = infos1[12].text
            except:
                playerstatrow['red'] = ''
            try:
                playerstatrow['penalty'] = infos1[13].text
            except:
                playerstatrow['penalty'] = ''
            infos2 = row.find_all('td', {'class' : 'rechts'})
            try:
                playerstatrow['minutes_per_goal'] = infos2[0].text
            except:
                playerstatrow['minutes_per_goal'] = ''
            try:
                playerstatrow['minutes_played'] = infos2[1].text
            except:
                playerstatrow['minutes_played'] = ''
            playerstats.append(playerstatrow)
    except:
        playerstats = ['']
    return playerstats

# %%
iniesta = get_player_stats('https://www.transfermarkt.co.uk/andres-iniesta/profil/spieler/7600')

# %%
pd.DataFrame(iniesta).iloc[10:20, :]
# Out:
#    season       competition in_squad appearances pointspermatch goals assists  \
# 10  15/16         Supercopa        2           2           0.50     -       -
# 11  14/15  Champions League       11          11           2.45     -       5
# 12  14/15            LaLiga       31          24           2.29     -       1
# 13  13/14      Copa del Rey        6           6           2.17     -       1
# 14  13/14         Supercopa        2           2           1.00     -       -
# 15  12/13  Champions League       10          10           1.40     1       1
# 16  12/13         Supercopa        2           2           1.50     -       2
# 17  11/12            LaLiga       31          27           2.52     2      10
# 18  11/12    Club World Cup        2           2           3.00     -       -
# 19  11/12         Supercopa        2           2           2.00     1       -
#
#    owngoals sub_on sub_off yellow secondyellow red penalty minutes_per_goal  \
# 10        -      1       -      1            -   -       -                -
# 11        -      1       7      -            -   -       -                -
# 12        -      5      14      3            -   -       -                -
# 13        -      2       2      -            -   -       -                -
# 14        -      1       -      -            -   -       -                -
# 15        -      1       1      1            -   -       -             803'
# 16        -      -       -      -            -   -       -                -
# 17        -      6      10      4            -   -       -             932'
# 18        -      -       -      -            -   -       -                -
# 19        -      -       -      -            -   -       -             180'
#
#    minutes_played
# 10           129'
# 11           786'
# 12         1.590'
# 13           321'
# 14           107'
# 15           803'
# 16           180'
# 17         1.864'
# 18           180'
# 19           180'

# %% [markdown]
# ### Player transfer data

# %%
def get_transfer_data(url):
    siker, soup = get_soup(url)
    try:
        box = soup.find('div', {'class' : 'box transferhistorie'})
        transfers = box.find_all('tr', {'class' : 'zeile-transfer'})
        transferstatrows = []
        for transfer in transfers:
            transferstat = {}
            try:
                transferstat['season'] = transfer.find_all('td', {'class' : 'zentriert hide-for-small'})[0].text
            except:
                transferstat['season'] = ''
            try:
                transferstat['date'] = transfer.find_all('td', {'class' : 'zentriert hide-for-small'})[1].text
            except:
                transferstat['date'] = ''
            try:
                transferstat['from_club'] = transfer.find_all('td', {'class' : 'hauptlink no-border-links hide-for-small vereinsname'})[0].text.strip()
            except:
                transferstat['from_club'] = ''
            try:
                transferstat['to_club'] = transfer.find_all('td', {'class' : 'hauptlink no-border-links hide-for-small vereinsname'})[1].text.strip()
            except:
                transferstat['to_club'] = ''
            try:
                transferstat['value'] = transfer.find('td', {'class' : 'zelle-mw'}).text.strip()
            except:
                transferstat['value'] = ''
            try:
                transferstat['price'] = transfer.find('td', {'class' : 'zelle-abloese'}).text.strip()
            except:
                transferstat['price'] = ''
            transferstatrows.append(transferstat)
    except:
        transferstatrows = ['']
    return transferstatrows

# %%
ibra = get_transfer_data('https://www.transfermarkt.co.uk/zlatan-ibrahimovic/profil/spieler/3455')

# %%
pd.DataFrame(ibra)
# Out:
#    season          date     from_club       to_club    value            price
# 0   19/20   Jan 2, 2020     LA Galaxy      AC Milan   £3.15m    Free transfer
# 1   17/18  Mar 23, 2018       Man Utd     LA Galaxy   £4.50m    Free transfer
# 2   16/17   Jul 1, 2016      Paris SG       Man Utd  £13.50m    Free transfer
# 3   12/13  Jul 18, 2012      AC Milan      Paris SG  £33.30m          £18.90m
# 4   11/12   Jul 1, 2011  FC Barcelona      AC Milan  £31.50m          £21.60m
# 5   10/11  Jun 30, 2011      AC Milan  FC Barcelona  £31.50m      End of loan
# 6   10/11  Aug 28, 2010  FC Barcelona      AC Milan  £40.50m  Loan fee:£5.40m
# 7   09/10  Jul 27, 2009         Inter  FC Barcelona  £40.50m          £62.55m
# 8   06/07  Aug 10, 2006      Juventus         Inter  £22.50m          £22.32m
# 9   04/05  Aug 31, 2004          Ajax      Juventus        -          £14.40m
# 10  01/02   Jul 1, 2001      Malmö FF          Ajax        -           £7.02m
# 11  98/99   Jan 1, 1999     Malmö U19      Malmö FF        -                -
# 12  97/98   Jan 1, 1998  Malmö FF U17     Malmö U19        -                -
# 13  95/96   Jul 1, 1995    FBK Balkan  Malmö FF U17        -                ?
# 14  91/92   Jul 1, 1991         Malmö    FBK Balkan        -    Free transfer

# %% [markdown]
# ### Get all player data

# %%
df = pd.read_csv('teams_dataframe_status0513.csv', sep = ';', encoding = 'utf-8').drop(columns = 'Unnamed: 0')
df.head()
# Out:
#         name                                                url  \
# 0   Man City  https://www.transfermarkt.co.uk/manchester-cit...
# 1  Liverpool  https://www.transfermarkt.co.uk/fc-liverpool/s...
# 2      Spurs  https://www.transfermarkt.co.uk/tottenham-hots...
# 3    Chelsea  https://www.transfermarkt.co.uk/fc-chelsea/sta...
# 4    Man Utd  https://www.transfermarkt.co.uk/manchester-uni...
#
#                                            squadlist  \
# 0  https://www.transfermarkt.co.uk/manchester-cit...
# 1  https://www.transfermarkt.co.uk/fc-liverpool/k...
# 2  https://www.transfermarkt.co.uk/tottenham-hots...
# 3  https://www.transfermarkt.co.uk/fc-chelsea/kad...
# 4  https://www.transfermarkt.co.uk/manchester-uni...
#
#                                            squaddata
# 0  [{'kit': '31', 'name': 'Ederson', 'genposition...
# 1  [{'kit': '1', 'name': 'Alisson', 'genposition'...
# 2  [{'kit': '1', 'name': 'Hugo Lloris', 'genposit...
# 3  [{'kit': '1', 'name': 'Kepa', 'genposition': '...
# 4  [{'kit': '1', 'name': 'David de Gea', 'genposi...

# %%
pd.DataFrame(eval(df['squaddata'][0]))
# Out:
#    kit                 name genposition        specposition  \
# 0   31              Ederson  Goalkeeper          Goalkeeper
# 1   33         Scott Carson  Goalkeeper          Goalkeeper
# 2    5          John Stones    Defender         Centre-Back
# 3   50          Eric García    Defender         Centre-Back
# 4   11  Oleksandr Zinchenko    Defender           Left-Back
# 5   27         João Cancelo    Defender          Right-Back
# 6   25          Fernandinho  Midfielder  Defensive Midfield
# 7   47           Phil Foden  Midfielder    Central Midfield
# 8   21          David Silva  Midfielder  Attacking Midfield
# 9   19           Leroy Sané     Forward         Left Winger
# 10  26         Riyad Mahrez     Forward        Right Winger
# 11  10        Sergio Agüero     Forward      Centre-Forward
# 12   1        Claudio Bravo  Goalkeeper          Goalkeeper
# 13  14      Aymeric Laporte    Defender         Centre-Back
# 14  30     Nicolás Otamendi    Defender         Centre-Back
# 15  22       Benjamin Mendy    Defender           Left-Back
# 16   2          Kyle Walker    Defender          Right-Back
# 17  16              Rodrigo  Midfielder  Defensive Midfield
# 18   8       Ilkay Gündogan  Midfielder    Central Midfield
# 19  17      Kevin De Bruyne  Midfielder  Attacking Midfield
# 20   7      Raheem Sterling     Forward         Left Winger
# 21  20       Bernardo Silva     Forward        Right Winger
# 22   9        Gabriel Jesus     Forward      Centre-Forward
#
#           dateofbirth nationality  height   foot        joined  \
# 0   Aug 17, 1993 (26)      Brazil  1,88 m   left   Jul 1, 2017
# 1    Sep 3, 1985 (34)     England  1,88 m  right   Aug 8, 2019
# 2   May 28, 1994 (25)     England  1,88 m  right   Aug 9, 2016
# 3    Jan 9, 2001 (19)       Spain  1,83 m  right   Jul 1, 2019
# 4   Dec 15, 1996 (23)     Ukraine  1,75 m   left   Jul 4, 2016
# 5   May 27, 1994 (25)    Portugal  1,82 m  right   Aug 7, 2019
# 6    May 4, 1985 (35)      Brazil  1,79 m  right   Jul 1, 2013
# 7   May 28, 2000 (19)     England  1,71 m   left   Jul 1, 2017
# 8    Jan 8, 1986 (34)       Spain  1,70 m   left  Jul 14, 2010
# 9   Jan 11, 1996 (24)     Germany  1,84 m   left   Aug 2, 2016
# 10  Feb 21, 1991 (29)     Algeria  1,79 m   left  Jul 10, 2018
# 11   Jun 2, 1988 (31)   Argentina  1,73 m  right  Jul 28, 2011
# 12  Apr 13, 1983 (37)       Chile  1,84 m  right  Aug 25, 2016
# 13  May 27, 1994 (25)      France  1,90 m   left  Jan 30, 2018
# 14  Feb 12, 1988 (32)   Argentina  1,83 m  right  Aug 20, 2015
# 15  Jul 17, 1994 (25)      France  1,85 m   left  Jul 24, 2017
# 16  May 28, 1990 (29)     England  1,83 m  right  Jul 14, 2017
# 17  Jun 22, 1996 (23)       Spain  1,91 m  right   Jul 4, 2019
# 18  Oct 24, 1990 (29)     Germany  1,80 m  right   Jul 1, 2016
# 19  Jun 28, 1991 (28)     Belgium  1,81 m  right  Aug 30, 2015
# 20   Dec 8, 1994 (25)     England  1,70 m  right  Jul 14, 2015
# 21  Aug 10, 1994 (25)    Portugal  1,73 m   left   Jul 1, 2017
# 22   Apr 3, 1997 (23)      Brazil  1,75 m  right   Jan 1, 2017
#
#                          lastclub    contract  \
# 0                      SL Benfica  30.06.2025
# 1                    Derby County  31.05.2020
# 2                      Everton FC  30.06.2022
# 3             Manchester City U23  30.06.2022
# 4                          FK Ufa  30.06.2024
# 5                     Juventus FC  30.06.2025
# 6                Shakhtar Donetsk  30.06.2021
# 7             Manchester City U18  30.06.2024
# 8                     Valencia CF  30.06.2020
# 9                   FC Schalke 04  30.06.2021
# 10                 Leicester City  30.06.2023
# 11                Atlético Madrid  30.06.2021
# 12                   FC Barcelona  30.06.2020
# 13                Athletic Bilbao  30.06.2025
# 14                    Valencia CF  30.06.2022
# 15                      AS Monaco  30.06.2023
# 16              Tottenham Hotspur  30.06.2024
# 17                Atlético Madrid  30.06.2024
# 18              Borussia Dortmund  30.06.2023
# 19                  VfL Wolfsburg  30.06.2023
# 20                   Liverpool FC  30.06.2023
# 21                      AS Monaco  30.06.2025
# 22  Sociedade Esportiva Palmeiras  30.06.2023
#
#                                             playerurl
# 0   https://www.transfermarkt.co.uk/ederson/profil...
# 1   https://www.transfermarkt.co.uk/scott-carson/p...
# 2   https://www.transfermarkt.co.uk/john-stones/pr...
# 3   https://www.transfermarkt.co.uk/eric-garcia/pr...
# 4   https://www.transfermarkt.co.uk/oleksandr-zinc...
# 5   https://www.transfermarkt.co.uk/joao-cancelo/p...
# 6   https://www.transfermarkt.co.uk/fernandinho/pr...
# 7   https://www.transfermarkt.co.uk/phil-foden/pro...
# 8   https://www.transfermarkt.co.uk/david-silva/pr...
# 9   https://www.transfermarkt.co.uk/leroy-sane/pro...
# 10  https://www.transfermarkt.co.uk/riyad-mahrez/p...
# 11  https://www.transfermarkt.co.uk/sergio-aguero/...
# 12  https://www.transfermarkt.co.uk/claudio-bravo/...
# 13  https://www.transfermarkt.co.uk/aymeric-laport...
# 14  https://www.transfermarkt.co.uk/nicolas-otamen...
# 15  https://www.transfermarkt.co.uk/benjamin-mendy...
# 16  https://www.transfermarkt.co.uk/kyle-walker/pr...
# 17  https://www.transfermarkt.co.uk/rodrigo/profil...
# 18  https://www.transfermarkt.co.uk/ilkay-gundogan...
# 19  https://www.transfermarkt.co.uk/kevin-de-bruyn...
# 20  https://www.transfermarkt.co.uk/raheem-sterlin...
# 21  https://www.transfermarkt.co.uk/bernardo-silva...
# 22  https://www.transfermarkt.co.uk/gabriel-jesus/...

# %% [markdown]
# Now we will iterate on all the players of all the squads and retreive the abovementioned information, and store them in the dataframe

# %%
def scrape_all_player_data(df):
    i = 0
    for squad in df['squaddata']:
        squad = eval(squad)
        for player in squad:
            player['marketvaluedata'] = get_market_values(player['playerurl'])
            player['performancestats'] = get_player_stats(player['playerurl'])
            player['playertransfers'] = get_transfer_data(player['playerurl'])
            filename = '../Code/Jsons/' + str(player['name']) + '.json'
            json.dump(player, open(filename, 'w'))
            print('Player done!')
        i += 1
        print(i, ' teams done!')
    return df

# %%
proba_df = scrape_all_player_data(new_df.head(1))
# Out:
# Player done!
# Player done!
# Player done!
# Player done!
# Player done!
# Player done!
# Player done!
# Player done!
# Player done!
# Player done!
# Player done!
# Player done!
# Player done!
# Player done!
# Player done!
# Player done!
# Player done!
# Player done!
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Player done!
# Player done!
# Player done!
# Player done!
# Player done!
# 1  teams done!

# %%
proba_df['squaddata'][0]
# Out:
# [{'kit': '31',
#   'name': 'Ederson',
#   'genposition': 'Goalkeeper',
#   'specposition': 'Goalkeeper',
#   'dateofbirth': 'Aug 17, 1993 (26)',
#   'nationality': 'Brazil',
#   'height': '1,88 m',
#   'foot': 'left',
#   'joined': 'Jul 1, 2017',
#   'lastclub': 'SL Benfica',
#   'contract': '30.06.2025',
#   'playerurl': 'https://www.transfermarkt.co.uk/ederson/profil/spieler/238223',
#   'marketvaluedata': {'date': ['Apr 3, 2013',
#     'Jul 2, 2013',
#     'Jul 25, 2014',
#     'Feb 17, 2015',
#     'Jul 1, 2015',
#     'Feb 24, 2016',
#     'Jul 29, 2016',
#     'Feb 22, 2017',
#     'Jun 26, 2017',
#     'Oct 23, 2017',
#     'Jan 2, 2018',
#     'Mar 23, 2018',
#     'May 28, 2018',
#     'Oct 17, 2018',
#     'Dec 19, 2018',
#     'Jun 13, 2019',
#     'Dec 10, 2019',
#     'Apr 8, 2020'],
#    'market_value': ['270000',
#     '270000',
#     '810000',
#     '540000',
#     '1080000',
#     '1080000',
#     '6300000',
#     '10800000',
#     '19800000',
#     '22500000',
#     '31500000',
#     '40500000',
#     '45000000',
#     '54000000',
#     '54000000',
#     '63000000',
#     '63000000',
#     '50400000']},
#   'performancestats': [{'season': '19/20',
#     'competition': 'Premier League',
#     'in_squad': '25',
#     'appearances': '25',
#     'pointspermatch': '2.04',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '3',
#     'yellow': '-',
#     'secondyellow': '1',
#     'red': '24',
#     'penalty': '10',
#     'minutes_per_goal': "2.172'",
#     'minutes_played': ''},
#    {'season': '19/20',
#     'competition': 'EFL Cup',
#     'in_squad': '3',
#     'appearances': '-',
#     'pointspermatch': '-',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': '-',
#     'minutes_played': ''},
#    {'season': '19/20',
#     'competition': 'Community Shield',
#     'in_squad': '1',
#     'appearances': '-',
#     'pointspermatch': '-',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': '-',
#     'minutes_played': ''},
#    {'season': '18/19',
#     'competition': 'Premier League',
#     'in_squad': '38',
#     'appearances': '38',
#     'pointspermatch': '2.58',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '2',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '23',
#     'penalty': '20',
#     'minutes_per_goal': "3.420'",
#     'minutes_played': ''},
#    {'season': '18/19',
#     'competition': 'EFL Cup',
#     'in_squad': '5',
#     'appearances': '1',
#     'pointspermatch': '3.00',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '1',
#     'minutes_per_goal': "120'",
#     'minutes_played': ''},
#    {'season': '17/18',
#     'competition': 'Premier League',
#     'in_squad': '38',
#     'appearances': '36',
#     'pointspermatch': '2.61',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '1',
#     'sub_off': '1',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '26',
#     'penalty': '17',
#     'minutes_per_goal': "3.195'",
#     'minutes_played': ''},
#    {'season': '17/18',
#     'competition': 'EFL Cup',
#     'in_squad': '6',
#     'appearances': '-',
#     'pointspermatch': '-',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': '-',
#     'minutes_played': ''},
#    {'season': '16/17',
#     'competition': 'Taça de Portugal Placard',
#     'in_squad': '6',
#     'appearances': '3',
#     'pointspermatch': '3.00',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '1',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '2',
#     'penalty': '1',
#     'minutes_per_goal': "270'",
#     'minutes_played': ''},
#    {'season': '16/17',
#     'competition': 'Champions League',
#     'in_squad': '8',
#     'appearances': '7',
#     'pointspermatch': '1.57',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '10',
#     'penalty': '3',
#     'minutes_per_goal': "630'",
#     'minutes_played': ''},
#    {'season': '15/16',
#     'competition': 'Allianz Cup',
#     'in_squad': '5',
#     'appearances': '5',
#     'pointspermatch': '3.00',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '4',
#     'penalty': '2',
#     'minutes_per_goal': "450'",
#     'minutes_played': ''},
#    {'season': '15/16',
#     'competition': 'Champions League',
#     'in_squad': '10',
#     'appearances': '3',
#     'pointspermatch': '1.33',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '4',
#     'penalty': '-',
#     'minutes_per_goal': "270'",
#     'minutes_played': ''},
#    {'season': '15/16',
#     'competition': 'Taça de Portugal Placard',
#     'in_squad': '1',
#     'appearances': '-',
#     'pointspermatch': '-',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '1',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': '-',
#     'minutes_played': ''},
#    {'season': '14/15',
#     'competition': 'Liga NOS',
#     'in_squad': '33',
#     'appearances': '17',
#     'pointspermatch': '1.18',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '3',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '18',
#     'penalty': '5',
#     'minutes_per_goal': "1.530'",
#     'minutes_played': ''},
#    {'season': '14/15',
#     'competition': 'Allianz Cup',
#     'in_squad': '5',
#     'appearances': '4',
#     'pointspermatch': '0.25',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '5',
#     'penalty': '-',
#     'minutes_per_goal': "360'",
#     'minutes_played': ''},
#    {'season': '14/15',
#     'competition': 'Supertaça',
#     'in_squad': '1',
#     'appearances': '-',
#     'pointspermatch': '-',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': '-',
#     'minutes_played': ''},
#    {'season': '13/14',
#     'competition': 'Taça de Portugal Placard',
#     'in_squad': '7',
#     'appearances': '7',
#     'pointspermatch': '2.29',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '3',
#     'penalty': '5',
#     'minutes_per_goal': "630'",
#     'minutes_played': ''},
#    {'season': '13/14',
#     'competition': 'Allianz Cup',
#     'in_squad': '5',
#     'appearances': '3',
#     'pointspermatch': '3.00',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '1',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '1',
#     'penalty': '2',
#     'minutes_per_goal': "202'",
#     'minutes_played': ''},
#    {'season': '12/13',
#     'competition': 'Allianz Cup',
#     'in_squad': '5',
#     'appearances': '4',
#     'pointspermatch': '1.00',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '1',
#     'sub_on': '-',
#     'sub_off': '1',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '9',
#     'penalty': '1',
#     'minutes_per_goal': "305'",
#     'minutes_played': ''},
#    {'season': '19/20',
#     'competition': 'FA Cup',
#     'in_squad': '2',
#     'appearances': '-',
#     'pointspermatch': '-',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': '-',
#     'minutes_played': ''},
#    {'season': '19/20',
#     'competition': 'Champions League',
#     'in_squad': '6',
#     'appearances': '6',
#     'pointspermatch': '2.33',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '1',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '3',
#     'penalty': '3',
#     'minutes_per_goal': "495'",
#     'minutes_played': ''},
#    {'season': '18/19',
#     'competition': 'FA Cup',
#     'in_squad': '6',
#     'appearances': '6',
#     'pointspermatch': '3.00',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '3',
#     'penalty': '4',
#     'minutes_per_goal': "540'",
#     'minutes_played': ''},
#    {'season': '18/19',
#     'competition': 'Champions League',
#     'in_squad': '10',
#     'appearances': '10',
#     'pointspermatch': '2.20',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '1',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '12',
#     'penalty': '3',
#     'minutes_per_goal': "900'",
#     'minutes_played': ''},
#    {'season': '18/19',
#     'competition': 'Community Shield',
#     'in_squad': '1',
#     'appearances': '-',
#     'pointspermatch': '-',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': '-',
#     'minutes_played': ''},
#    {'season': '17/18',
#     'competition': 'Champions League',
#     'in_squad': '10',
#     'appearances': '9',
#     'pointspermatch': '2.00',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '1',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '10',
#     'penalty': '4',
#     'minutes_per_goal': "810'",
#     'minutes_played': ''},
#    {'season': '17/18',
#     'competition': 'FA Cup',
#     'in_squad': '3',
#     'appearances': '-',
#     'pointspermatch': '-',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': '-',
#     'minutes_played': ''},
#    {'season': '16/17',
#     'competition': 'Liga NOS',
#     'in_squad': '31',
#     'appearances': '27',
#     'pointspermatch': '2.41',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '4',
#     'yellow': '-',
#     'secondyellow': '1',
#     'red': '12',
#     'penalty': '18',
#     'minutes_per_goal': "2.382'",
#     'minutes_played': ''},
#    {'season': '16/17',
#     'competition': 'Allianz Cup',
#     'in_squad': '4',
#     'appearances': '3',
#     'pointspermatch': '2.00',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '3',
#     'penalty': '2',
#     'minutes_per_goal': "270'",
#     'minutes_played': ''},
#    {'season': '15/16',
#     'competition': 'Liga NOS',
#     'in_squad': '33',
#     'appearances': '10',
#     'pointspermatch': '3.00',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '1',
#     'sub_off': '2',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '4',
#     'penalty': '6',
#     'minutes_per_goal': "891'",
#     'minutes_played': ''},
#    {'season': '15/16',
#     'competition': 'Liga Pro',
#     'in_squad': '4',
#     'appearances': '4',
#     'pointspermatch': '1.50',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '1',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '6',
#     'penalty': '1',
#     'minutes_per_goal': "360'",
#     'minutes_played': ''},
#    {'season': '15/16',
#     'competition': 'Supertaça',
#     'in_squad': '1',
#     'appearances': '-',
#     'pointspermatch': '-',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': '-',
#     'minutes_played': ''},
#    {'season': '14/15',
#     'competition': 'Taça de Portugal Placard',
#     'in_squad': '6',
#     'appearances': '5',
#     'pointspermatch': '2.00',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '1',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '6',
#     'penalty': '2',
#     'minutes_per_goal': "450'",
#     'minutes_played': ''},
#    {'season': '14/15',
#     'competition': 'Europa League',
#     'in_squad': '8',
#     'appearances': '2',
#     'pointspermatch': '0.50',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '4',
#     'penalty': '-',
#     'minutes_per_goal': "180'",
#     'minutes_played': ''},
#    {'season': '14/15',
#     'competition': 'Europa League Qualifying',
#     'in_squad': '2',
#     'appearances': '-',
#     'pointspermatch': '-',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': '-',
#     'minutes_played': ''},
#    {'season': '13/14',
#     'competition': 'Liga NOS',
#     'in_squad': '29',
#     'appearances': '18',
#     'pointspermatch': '1.06',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '1',
#     'sub_on': '-',
#     'sub_off': '5',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '23',
#     'penalty': '6',
#     'minutes_per_goal': "1.595'",
#     'minutes_played': ''},
#    {'season': '12/13',
#     'competition': 'Liga NOS',
#     'in_squad': '22',
#     'appearances': '2',
#     'pointspermatch': '1.50',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '2',
#     'penalty': '-',
#     'minutes_per_goal': "180'",
#     'minutes_played': ''},
#    {'season': '12/13',
#     'competition': 'Taça de Portugal Placard',
#     'in_squad': '2',
#     'appearances': '2',
#     'pointspermatch': '1.50',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '3',
#     'penalty': '-',
#     'minutes_per_goal': "210'",
#     'minutes_played': ''}],
#   'playertransfers': [{'season': '17/18',
#     'date': 'Jul 1, 2017',
#     'from_club': 'Benfica',
#     'to_club': 'Man City',
#     'value': '£19.80m',
#     'price': '£36.00m'},
#    {'season': '15/16',
#     'date': 'Jul 1, 2015',
#     'from_club': 'Rio Ave FC',
#     'to_club': 'Benfica',
#     'value': '£1.08m',
#     'price': '£450Th.'},
#    {'season': '12/13',
#     'date': 'Jul 1, 2012',
#     'from_club': 'GD Ribeirão',
#     'to_club': 'Rio Ave FC',
#     'value': '-',
#     'price': 'Free transfer'},
#    {'season': '11/12',
#     'date': 'Jul 1, 2011',
#     'from_club': 'Benfica U19',
#     'to_club': 'GD Ribeirão',
#     'value': '-',
#     'price': 'Free transfer'},
#    {'season': '10/11',
#     'date': 'Jul 1, 2010',
#     'from_club': 'Benfica U17',
#     'to_club': 'Benfica U19',
#     'value': '-',
#     'price': '-'},
#    {'season': '09/10',
#     'date': 'Jan 1, 2010',
#     'from_club': 'São Paulo U17',
#     'to_club': 'Benfica U17',
#     'value': '-',
#     'price': '?'}]},
#  {'kit': '33',
#   'name': 'Scott Carson',
#   'genposition': 'Goalkeeper',
#   'specposition': 'Goalkeeper',
#   'dateofbirth': 'Sep 3, 1985 (34)',
#   'nationality': 'England',
#   'height': '1,88 m',
#   'foot': 'right',
#   'joined': 'Aug 8, 2019',
#   'lastclub': 'Derby County',
#   'contract': '31.05.2020',
#   'playerurl': 'https://www.transfermarkt.co.uk/scott-carson/profil/spieler/14555',
#   'marketvaluedata': {'date': ['Oct 4, 2004',
#     'Jan 21, 2005',
#     'Feb 2, 2005',
#     'Nov 18, 2005',
#     'May 3, 2007',
#     'Jan 21, 2008',
#     'Jul 4, 2008',
#     'Feb 23, 2009',
#     'Jun 25, 2009',
#     'Dec 9, 2009',
#     'Jul 19, 2010',
#     'Feb 1, 2011',
#     'Aug 22, 2011',
#     'Jan 9, 2012',
#     'Jun 19, 2012',
#     'Jan 6, 2013',
#     'Jun 14, 2013',
#     'Sep 18, 2013',
#     'Jan 8, 2014',
#     'Feb 24, 2015',
#     'Sep 24, 2015',
#     'Apr 20, 2016',
#     'Sep 1, 2016',
#     'Feb 27, 2017',
#     'Sep 18, 2017',
#     'Feb 27, 2018',
#     'Sep 24, 2018',
#     'Jun 28, 2019',
#     'Dec 10, 2019',
#     'Apr 8, 2020'],
#    'market_value': ['360000',
#     '675000',
#     '1350000',
#     '1575000',
#     '2250000',
#     '4725000',
#     '5400000',
#     '4950000',
#     '4320000',
#     '3375000',
#     '3150000',
#     '3150000',
#     '2790000',
#     '3420000',
#     '3600000',
#     '3780000',
#     '3780000',
#     '2250000',
#     '2250000',
#     '1800000',
#     '1800000',
#     '1800000',
#     '1800000',
#     '1800000',
#     '2250000',
#     '2700000',
#     '2700000',
#     '1800000',
#     '900000',
#     '720000']},
#   'performancestats': [{'season': '19/20',
#     'competition': 'FA Cup',
#     'in_squad': '1',
#     'appearances': '-',
#     'pointspermatch': '-',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': '-',
#     'minutes_played': ''},
#    {'season': '19/20',
#     'competition': 'EFL Cup',
#     'in_squad': '3',
#     'appearances': '-',
#     'pointspermatch': '-',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': '-',
#     'minutes_played': ''},
#    {'season': '18/19',
#     'competition': 'Championship Play-Offs',
#     'in_squad': '3',
#     'appearances': '-',
#     'pointspermatch': '-',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': '-',
#     'minutes_played': ''},
#    {'season': '18/19',
#     'competition': 'FA Cup',
#     'in_squad': '2',
#     'appearances': '-',
#     'pointspermatch': '-',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': '-',
#     'minutes_played': ''},
#    {'season': '17/18',
#     'competition': 'Championship Play-Offs',
#     'in_squad': '2',
#     'appearances': '2',
#     'pointspermatch': '1.50',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '2',
#     'penalty': '1',
#     'minutes_per_goal': "180'",
#     'minutes_played': ''},
#    {'season': '17/18',
#     'competition': 'FA Cup',
#     'in_squad': '1',
#     'appearances': '1',
#     'pointspermatch': '0,00',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '2',
#     'penalty': '-',
#     'minutes_per_goal': "90'",
#     'minutes_played': ''},
#    {'season': '16/17',
#     'competition': 'Championship',
#     'in_squad': '46',
#     'appearances': '46',
#     'pointspermatch': '1.46',
#     'goals': '-',
#     'assists': '1',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '2',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '50',
#     'penalty': '17',
#     'minutes_per_goal': "4.140'",
#     'minutes_played': ''},
#    {'season': '16/17',
#     'competition': 'EFL Cup',
#     'in_squad': '2',
#     'appearances': '2',
#     'pointspermatch': '3.00',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '1',
#     'penalty': '1',
#     'minutes_per_goal': "210'",
#     'minutes_played': ''},
#    {'season': '15/16',
#     'competition': 'Championship',
#     'in_squad': '38',
#     'appearances': '36',
#     'pointspermatch': '1.72',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '32',
#     'penalty': '15',
#     'minutes_per_goal': "3.240'",
#     'minutes_played': ''},
#    {'season': '15/16',
#     'competition': 'League Cup',
#     'in_squad': '1',
#     'appearances': '-',
#     'pointspermatch': '-',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': '-',
#     'minutes_played': ''},
#    {'season': '13/14',
#     'competition': 'Championship Play-Offs',
#     'in_squad': '2',
#     'appearances': '2',
#     'pointspermatch': '0.50',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '2',
#     'penalty': '1',
#     'minutes_per_goal': "210'",
#     'minutes_played': ''},
#    {'season': '13/14',
#     'competition': 'FA Cup',
#     'in_squad': '2',
#     'appearances': '2',
#     'pointspermatch': '1.50',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '1',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '2',
#     'penalty': '-',
#     'minutes_per_goal': "210'",
#     'minutes_played': ''},
#    {'season': '13/14',
#     'competition': 'League Cup',
#     'in_squad': '1',
#     'appearances': '-',
#     'pointspermatch': '-',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': '-',
#     'minutes_played': ''},
#    {'season': '12/13',
#     'competition': 'Süper Lig',
#     'in_squad': '29',
#     'appearances': '29',
#     'pointspermatch': '1.72',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '1',
#     'sub_off': '5',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '33',
#     'penalty': '10',
#     'minutes_per_goal': "2.565'",
#     'minutes_played': ''},
#    {'season': '12/13',
#     'competition': 'Europa League',
#     'in_squad': '2',
#     'appearances': '2',
#     'pointspermatch': '1.50',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '1',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '5',
#     'penalty': '-',
#     'minutes_per_goal': "210'",
#     'minutes_played': ''},
#    {'season': '11/12',
#     'competition': 'Türkiye Kupasi',
#     'in_squad': '3',
#     'appearances': '3',
#     'pointspermatch': '2.00',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '5',
#     'penalty': '1',
#     'minutes_per_goal': "270'",
#     'minutes_played': ''},
#    {'season': '11/12',
#     'competition': 'Süper Lig',
#     'in_squad': '32',
#     'appearances': '32',
#     'pointspermatch': '1.41',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '6',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '32',
#     'penalty': '13',
#     'minutes_per_goal': "2.880'",
#     'minutes_played': ''},
#    {'season': '11/12',
#     'competition': 'Europa League Qualifying',
#     'in_squad': '2',
#     'appearances': '2',
#     'pointspermatch': '3.00',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '2',
#     'penalty': '-',
#     'minutes_per_goal': "180'",
#     'minutes_played': ''},
#    {'season': '10/11',
#     'competition': 'FA Cup',
#     'in_squad': '1',
#     'appearances': '-',
#     'pointspermatch': '-',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': '-',
#     'minutes_played': ''},
#    {'season': '09/10',
#     'competition': 'Championship',
#     'in_squad': '43',
#     'appearances': '43',
#     'pointspermatch': '1.95',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '1',
#     'sub_off': '2',
#     'yellow': '-',
#     'secondyellow': '1',
#     'red': '44',
#     'penalty': '14',
#     'minutes_per_goal': "3.818'",
#     'minutes_played': ''},
#    {'season': '09/10',
#     'competition': 'League Cup',
#     'in_squad': '3',
#     'appearances': '-',
#     'pointspermatch': '-',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': '-',
#     'minutes_played': ''},
#    {'season': '08/09',
#     'competition': 'FA Cup',
#     'in_squad': '4',
#     'appearances': '4',
#     'pointspermatch': '1.25',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '6',
#     'penalty': '1',
#     'minutes_per_goal': "360'",
#     'minutes_played': ''},
#    {'season': '07/08',
#     'competition': 'Premier League',
#     'in_squad': '35',
#     'appearances': '35',
#     'pointspermatch': '1.66',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '1',
#     'yellow': '-',
#     'secondyellow': '1',
#     'red': '45',
#     'penalty': '9',
#     'minutes_per_goal': "3.126'",
#     'minutes_played': ''},
#    {'season': '07/08',
#     'competition': 'League Cup',
#     'in_squad': '2',
#     'appearances': '-',
#     'pointspermatch': '-',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': '-',
#     'minutes_played': ''},
#    {'season': '06/07',
#     'competition': 'League Cup',
#     'in_squad': '2',
#     'appearances': '2',
#     'pointspermatch': '1.50',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '4',
#     'penalty': '-',
#     'minutes_per_goal': "210'",
#     'minutes_played': ''},
#    {'season': '05/06',
#     'competition': 'FA Cup',
#     'in_squad': '2',
#     'appearances': '1',
#     'pointspermatch': '3.00',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '1',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '3',
#     'penalty': '-',
#     'minutes_per_goal': "90'",
#     'minutes_played': ''},
#    {'season': '05/06',
#     'competition': 'League Cup',
#     'in_squad': '1',
#     'appearances': '1',
#     'pointspermatch': '0,00',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '2',
#     'penalty': '-',
#     'minutes_per_goal': "90'",
#     'minutes_played': ''},
#    {'season': '05/06',
#     'competition': 'UEFA Super Cup',
#     'in_squad': '1',
#     'appearances': '-',
#     'pointspermatch': '-',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': '-',
#     'minutes_played': ''},
#    {'season': '05/06',
#     'competition': 'Premier League',
#     'in_squad': '2',
#     'appearances': '-',
#     'pointspermatch': '-',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': '-',
#     'minutes_played': ''},
#    {'season': '04/05',
#     'competition': 'Premier League',
#     'in_squad': '5',
#     'appearances': '4',
#     'pointspermatch': '1.50',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '3',
#     'penalty': '1',
#     'minutes_per_goal': "360'",
#     'minutes_played': ''},
#    {'season': '04/05',
#     'competition': 'Championship',
#     'in_squad': '29',
#     'appearances': '-',
#     'pointspermatch': '-',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': '-',
#     'minutes_played': ''},
#    {'season': '03/04',
#     'competition': 'League Cup',
#     'in_squad': '1',
#     'appearances': '-',
#     'pointspermatch': '-',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': '-',
#     'minutes_played': ''},
#    {'season': '19/20',
#     'competition': 'Premier League',
#     'in_squad': '3',
#     'appearances': '-',
#     'pointspermatch': '-',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': '-',
#     'minutes_played': ''},
#    {'season': '19/20',
#     'competition': 'Champions League',
#     'in_squad': '2',
#     'appearances': '-',
#     'pointspermatch': '-',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': '-',
#     'minutes_played': ''},
#    {'season': '18/19',
#     'competition': 'Championship',
#     'in_squad': '41',
#     'appearances': '30',
#     'pointspermatch': '1.57',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '1',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '40',
#     'penalty': '5',
#     'minutes_per_goal': "2.700'",
#     'minutes_played': ''},
#    {'season': '18/19',
#     'competition': 'EFL Cup',
#     'in_squad': '4',
#     'appearances': '3',
#     'pointspermatch': '2.00',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '5',
#     'penalty': '1',
#     'minutes_per_goal': "270'",
#     'minutes_played': ''},
#    {'season': '17/18',
#     'competition': 'Championship',
#     'in_squad': '46',
#     'appearances': '46',
#     'pointspermatch': '1.63',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '2',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '48',
#     'penalty': '19',
#     'minutes_per_goal': "4.140'",
#     'minutes_played': ''},
#    {'season': '17/18',
#     'competition': 'EFL Cup',
#     'in_squad': '1',
#     'appearances': '-',
#     'pointspermatch': '-',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': '-',
#     'minutes_played': ''},
#    {'season': '16/17',
#     'competition': 'FA Cup',
#     'in_squad': '3',
#     'appearances': '2',
#     'pointspermatch': '2.00',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '3',
#     'penalty': '-',
#     'minutes_per_goal': "210'",
#     'minutes_played': ''},
#    {'season': '15/16',
#     'competition': 'Championship Play-Offs',
#     'in_squad': '2',
#     'appearances': '2',
#     'pointspermatch': '1.50',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '3',
#     'penalty': '1',
#     'minutes_per_goal': "180'",
#     'minutes_played': ''},
#    {'season': '15/16',
#     'competition': 'FA Cup',
#     'in_squad': '1',
#     'appearances': '1',
#     'pointspermatch': '0,00',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '3',
#     'penalty': '-',
#     'minutes_per_goal': "90'",
#     'minutes_played': ''},
#    {'season': '14/15',
#     'competition': 'Championship',
#     'in_squad': '44',
#     'appearances': '34',
#     'pointspermatch': '0.91',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '44',
#     'penalty': '8',
#     'minutes_per_goal': "3.060'",
#     'minutes_played': ''},
#    {'season': '13/14',
#     'competition': 'Championship',
#     'in_squad': '27',
#     'appearances': '16',
#     'pointspermatch': '1.25',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '22',
#     'penalty': '3',
#     'minutes_per_goal': "1.440'",
#     'minutes_played': ''},
#    {'season': '13/14',
#     'competition': 'Europa League',
#     'in_squad': '4',
#     'appearances': '4',
#     'pointspermatch': '1.25',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '4',
#     'penalty': '1',
#     'minutes_per_goal': "360'",
#     'minutes_played': ''},
#    {'season': '13/14',
#     'competition': 'Community Shield',
#     'in_squad': '1',
#     'appearances': '1',
#     'pointspermatch': '0,00',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '2',
#     'penalty': '-',
#     'minutes_per_goal': "90'",
#     'minutes_played': ''},
#    {'season': '12/13',
#     'competition': 'Türkiye Kupasi',
#     'in_squad': '3',
#     'appearances': '3',
#     'pointspermatch': '0.33',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '6',
#     'penalty': '1',
#     'minutes_per_goal': "270'",
#     'minutes_played': ''},
#    {'season': '12/13',
#     'competition': 'Europa League Qualifying',
#     'in_squad': '2',
#     'appearances': '2',
#     'pointspermatch': '1.50',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '1',
#     'penalty': '1',
#     'minutes_per_goal': "180'",
#     'minutes_played': ''},
#    {'season': '11/12',
#     'competition': 'Süper Final - Europe League Play off',
#     'in_squad': '2',
#     'appearances': '2',
#     'pointspermatch': '3.00',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '2',
#     'penalty': '1',
#     'minutes_per_goal': "180'",
#     'minutes_played': ''},
#    {'season': '11/12',
#     'competition': 'Europa League',
#     'in_squad': '2',
#     'appearances': '2',
#     'pointspermatch': '0.50',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '4',
#     'penalty': '-',
#     'minutes_per_goal': "180'",
#     'minutes_played': ''},
#    {'season': '10/11',
#     'competition': 'Premier League',
#     'in_squad': '37',
#     'appearances': '32',
#     'pointspermatch': '1.28',
#     'goals': '-',
#     'assists': '1',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '1',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '58',
#     'penalty': '2',
#     'minutes_per_goal': "2.880'",
#     'minutes_played': ''},
#    {'season': '10/11',
#     'competition': 'League Cup',
#     'in_squad': '4',
#     'appearances': '-',
#     'pointspermatch': '-',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': '-',
#     'minutes_played': ''},
#    {'season': '09/10',
#     'competition': 'FA Cup',
#     'in_squad': '4',
#     'appearances': '4',
#     'pointspermatch': '1.75',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '1',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '7',
#     'penalty': '1',
#     'minutes_per_goal': "390'",
#     'minutes_played': ''},
#    {'season': '08/09',
#     'competition': 'Premier League',
#     'in_squad': '37',
#     'appearances': '35',
#     'pointspermatch': '0.80',
#     'goals': '-',
#     'assists': '2',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '3',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '64',
#     'penalty': '7',
#     'minutes_per_goal': "3.150'",
#     'minutes_played': ''},
#    {'season': '08/09',
#     'competition': 'League Cup',
#     'in_squad': '1',
#     'appearances': '-',
#     'pointspermatch': '-',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': '-',
#     'minutes_played': ''},
#    {'season': '07/08',
#     'competition': 'FA Cup',
#     'in_squad': '1',
#     'appearances': '1',
#     'pointspermatch': '0,00',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '2',
#     'penalty': '-',
#     'minutes_per_goal': "90'",
#     'minutes_played': ''},
#    {'season': '06/07',
#     'competition': 'Premier League',
#     'in_squad': '36',
#     'appearances': '36',
#     'pointspermatch': '0.92',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '1',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '55',
#     'penalty': '11',
#     'minutes_per_goal': "3.240'",
#     'minutes_played': ''},
#    {'season': '05/06',
#     'competition': 'Championship',
#     'in_squad': '9',
#     'appearances': '9',
#     'pointspermatch': '2.00',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '5',
#     'penalty': '5',
#     'minutes_per_goal': "810'",
#     'minutes_played': ''},
#    {'season': '05/06',
#     'competition': 'Club World Cup',
#     'in_squad': '2',
#     'appearances': '-',
#     'pointspermatch': '-',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': '-',
#     'minutes_played': ''},
#    {'season': '05/06',
#     'competition': 'Champions League',
#     'in_squad': '1',
#     'appearances': '-',
#     'pointspermatch': '-',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': '-',
#     'minutes_played': ''},
#    {'season': '05/06',
#     'competition': 'Champions League Qualifying',
#     'in_squad': '4',
#     'appearances': '2',
#     'pointspermatch': '1.50',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '1',
#     'penalty': '1',
#     'minutes_per_goal': "180'",
#     'minutes_played': ''},
#    {'season': '04/05',
#     'competition': 'Champions League',
#     'in_squad': '6',
#     'appearances': '1',
#     'pointspermatch': '3.00',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '1',
#     'penalty': '-',
#     'minutes_per_goal': "120'",
#     'minutes_played': ''},
#    {'season': '04/05',
#     'competition': 'League Cup',
#     'in_squad': '2',
#     'appearances': '-',
#     'pointspermatch': '-',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': '-',
#     'minutes_played': ''},
#    {'season': '03/04',
#     'competition': 'Premier League',
#     'in_squad': '3',
#     'appearances': '3',
#     'pointspermatch': '0.33',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '1',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '2',
#     'penalty': '1',
#     'minutes_per_goal': "181'",
#     'minutes_played': ''}],
#   'playertransfers': [{'season': '19/20',
#     'date': 'Aug 8, 2019',
#     'from_club': 'Derby',
#     'to_club': 'Man City',
#     'value': '£1.80m',
#     'price': 'Loan'},
#    {'season': '15/16',
#     'date': 'Jul 1, 2015',
#     'from_club': 'Wigan',
#     'to_club': 'Derby',
#     'value': '£1.80m',
#     'price': '?'},
#    {'season': '13/14',
#     'date': 'Jul 4, 2013',
#     'from_club': 'Bursaspor',
#     'to_club': 'Wigan',
#     'value': '£3.78m',
#     'price': '£738Th.'},
#    {'season': '11/12',
#     'date': 'Jul 1, 2011',
#     'from_club': 'West Brom',
#     'to_club': 'Bursaspor',
#     'value': '£3.15m',
#     'price': '£1.98m'},
#    {'season': '08/09',
#     'date': 'Jul 18, 2008',
#     'from_club': 'Liverpool',
#     'to_club': 'West Brom',
#     'value': '£5.40m',
#     'price': '£3.60m'},
#    {'season': '07/08',
#     'date': 'Jun 30, 2008',
#     'from_club': 'Aston Villa',
#     'to_club': 'Liverpool',
#     'value': '£4.73m',
#     'price': 'End of loan'},
#    {'season': '07/08',
#     'date': 'Aug 10, 2007',
#     'from_club': 'Liverpool',
#     'to_club': 'Aston Villa',
#     'value': '£2.25m',
#     'price': 'Loan'},
#    {'season': '06/07',
#     'date': 'Jul 8, 2007',
#     'from_club': 'Charlton',
#     'to_club': 'Liverpool',
#     'value': '£2.25m',
#     'price': 'End of loan'},
#    {'season': '06/07',
#     'date': 'Aug 16, 2006',
#     'from_club': 'Liverpool',
#     'to_club': 'Charlton',
#     'value': '£1.58m',
#     'price': 'Loan'},
#    {'season': '05/06',
#     'date': 'May 1, 2006',
#     'from_club': 'Sheff Wed',
#     'to_club': 'Liverpool',
#     'value': '£1.58m',
#     'price': 'End of loan'},
#    {'season': '05/06',
#     'date': 'Mar 10, 2006',
#     'from_club': 'Liverpool',
#     'to_club': 'Sheff Wed',
#     'value': '£1.58m',
#     'price': 'Loan'},
#    {'season': '04/05',
#     'date': 'Jan 21, 2005',
#     'from_club': 'Leeds',
#     'to_club': 'Liverpool',
#     'value': '£675Th.',
#     'price': '£1.26m'},
#    {'season': '03/04',
#     'date': 'Jul 1, 2003',
#     'from_club': 'Leeds U18',
#     'to_club': 'Leeds',
#     'value': '-',
#     'price': '-'}]},
#  {'kit': '5',
#   'name': 'John Stones',
#   'genposition': 'Defender',
#   'specposition': 'Centre-Back',
#   'dateofbirth': 'May 28, 1994 (25)',
#   'nationality': 'England',
#   'height': '1,88 m',
#   'foot': 'right',
#   'joined': 'Aug 9, 2016',
#   'lastclub': 'Everton FC',
#   'contract': '30.06.2022',
#   'playerurl': 'https://www.transfermarkt.co.uk/john-stones/profil/spieler/186590',
#   'marketvaluedata': {'date': ['Aug 15, 2011',
#     'Dec 10, 2012',
#     'Feb 3, 2013',
#     'Jul 2, 2013',
#     'Jan 15, 2014',
#     'Aug 12, 2014',
#     'Feb 12, 2015',
#     'Jul 1, 2015',
#     'Oct 14, 2015',
#     'Feb 9, 2016',
#     'Jun 1, 2016',
#     'Aug 1, 2016',
#     'Oct 24, 2016',
#     'Feb 20, 2017',
#     'Jun 28, 2017',
#     'Jan 2, 2018',
#     'Mar 23, 2018',
#     'May 28, 2018',
#     'Jul 16, 2018',
#     'Dec 19, 2018',
#     'Jun 13, 2019',
#     'Dec 10, 2019',
#     'Mar 9, 2020',
#     'Apr 8, 2020'],
#    'market_value': ['45000',
#     '90000',
#     '3150000',
#     '3150000',
#     '3600000',
#     '6300000',
#     '9000000',
#     '11700000',
#     '22500000',
#     '27000000',
#     '25200000',
#     '25200000',
#     '31500000',
#     '31500000',
#     '31500000',
#     '36000000',
#     '45000000',
#     '45000000',
#     '49500000',
#     '54000000',
#     '54000000',
#     '54000000',
#     '40500000',
#     '32400000']},
#   'performancestats': [{'season': '19/20',
#     'competition': 'FA Cup',
#     'in_squad': '3',
#     'appearances': '3',
#     'pointspermatch': '3.00',
#     'goals': '-',
#     'assists': '1',
#     'owngoals': '-',
#     'sub_on': '1',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': '-',
#     'minutes_played': "196'"},
#    {'season': '19/20',
#     'competition': 'Premier League',
#     'in_squad': '14',
#     'appearances': '12',
#     'pointspermatch': '1.92',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '2',
#     'sub_off': '1',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': '-',
#     'minutes_played': "904'"},
#    {'season': '19/20',
#     'competition': 'Community Shield',
#     'in_squad': '1',
#     'appearances': '1',
#     'pointspermatch': '3.00',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': '-',
#     'minutes_played': "120'"},
#    {'season': '18/19',
#     'competition': 'Premier League',
#     'in_squad': '34',
#     'appearances': '24',
#     'pointspermatch': '2.42',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '4',
#     'sub_off': '2',
#     'yellow': '1',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': '-',
#     'minutes_played': "1.762'"},
#    {'season': '18/19',
#     'competition': 'EFL Cup',
#     'in_squad': '5',
#     'appearances': '3',
#     'pointspermatch': '3.00',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': '-',
#     'minutes_played': "270'"},
#    {'season': '17/18',
#     'competition': 'Premier League',
#     'in_squad': '22',
#     'appearances': '18',
#     'pointspermatch': '2.61',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '2',
#     'sub_off': '5',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': '-',
#     'minutes_played': "1.305'"},
#    {'season': '17/18',
#     'competition': 'EFL Cup',
#     'in_squad': '5',
#     'appearances': '4',
#     'pointspermatch': '3.00',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '1',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': '-',
#     'minutes_played': "299'"},
#    {'season': '16/17',
#     'competition': 'Premier League',
#     'in_squad': '31',
#     'appearances': '27',
#     'pointspermatch': '1.89',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '4',
#     'sub_off': '3',
#     'yellow': '1',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': '-',
#     'minutes_played': "2.013'"},
#    {'season': '16/17',
#     'competition': 'FA Cup',
#     'in_squad': '5',
#     'appearances': '4',
#     'pointspermatch': '2.50',
#     'goals': '1',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': "360'",
#     'minutes_played': "360'"},
#    {'season': '16/17',
#     'competition': 'Champions League Qualifying',
#     'in_squad': '2',
#     'appearances': '2',
#     'pointspermatch': '3.00',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '1',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': '-',
#     'minutes_played': "150'"},
#    {'season': '15/16',
#     'competition': 'FA Cup',
#     'in_squad': '4',
#     'appearances': '2',
#     'pointspermatch': '1.50',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '1',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': '-',
#     'minutes_played': "92'"},
#    {'season': '14/15',
#     'competition': 'Premier League',
#     'in_squad': '28',
#     'appearances': '23',
#     'pointspermatch': '1.22',
#     'goals': '1',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '1',
#     'yellow': '1',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': "2.044'",
#     'minutes_played': "2.044'"},
#    {'season': '14/15',
#     'competition': 'FA Cup',
#     'in_squad': '2',
#     'appearances': '2',
# ...
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '1',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': '-',
#     'minutes_played': "8'"},
#    {'season': '13/14',
#     'competition': 'Allianz Cup',
#     'in_squad': '1',
#     'appearances': '1',
#     'pointspermatch': '3.00',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '1',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': '-',
#     'minutes_played': "13'"},
#    {'season': '19/20',
#     'competition': 'FA Cup',
#     'in_squad': '3',
#     'appearances': '3',
#     'pointspermatch': '3.00',
#     'goals': '1',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '1',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': "257'",
#     'minutes_played': "257'"},
#    {'season': '19/20',
#     'competition': 'Champions League',
#     'in_squad': '7',
#     'appearances': '6',
#     'pointspermatch': '2.33',
#     'goals': '-',
#     'assists': '1',
#     'owngoals': '-',
#     'sub_on': '1',
#     'sub_off': '2',
#     'yellow': '1',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': '-',
#     'minutes_played': "412'"},
#    {'season': '18/19',
#     'competition': 'FA Cup',
#     'in_squad': '6',
#     'appearances': '4',
#     'pointspermatch': '3.00',
#     'goals': '2',
#     'assists': '3',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': "180'",
#     'minutes_played': "360'"},
#    {'season': '18/19',
#     'competition': 'Champions League',
#     'in_squad': '8',
#     'appearances': '8',
#     'pointspermatch': '2.63',
#     'goals': '4',
#     'assists': '2',
#     'owngoals': '-',
#     'sub_on': '2',
#     'sub_off': '1',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': "145'",
#     'minutes_played': "578'"},
#    {'season': '18/19',
#     'competition': 'Community Shield',
#     'in_squad': '1',
#     'appearances': '1',
#     'pointspermatch': '3.00',
#     'goals': '-',
#     'assists': '1',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': '-',
#     'minutes_played': "90'"},
#    {'season': '17/18',
#     'competition': 'Champions League',
#     'in_squad': '10',
#     'appearances': '9',
#     'pointspermatch': '2.00',
#     'goals': '1',
#     'assists': '2',
#     'owngoals': '-',
#     'sub_on': '3',
#     'sub_off': '1',
#     'yellow': '1',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': "563'",
#     'minutes_played': "563'"},
#    {'season': '17/18',
#     'competition': 'FA Cup',
#     'in_squad': '3',
#     'appearances': '3',
#     'pointspermatch': '2.00',
#     'goals': '1',
#     'assists': '1',
#     'owngoals': '-',
#     'sub_on': '1',
#     'sub_off': '1',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': "190'",
#     'minutes_played': "190'"},
#    {'season': '16/17',
#     'competition': 'Champions League',
#     'in_squad': '11',
#     'appearances': '11',
#     'pointspermatch': '1.82',
#     'goals': '2',
#     'assists': '1',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '6',
#     'yellow': '1',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': "461'",
#     'minutes_played': "921'"},
#    {'season': '16/17',
#     'competition': 'Coupe de la Ligue',
#     'in_squad': '4',
#     'appearances': '3',
#     'pointspermatch': '2.00',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '1',
#     'sub_off': '1',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': '-',
#     'minutes_played': "232'"},
#    {'season': '15/16',
#     'competition': 'Ligue 1',
#     'in_squad': '32',
#     'appearances': '32',
#     'pointspermatch': '1.59',
#     'goals': '7',
#     'assists': '1',
#     'owngoals': '-',
#     'sub_on': '10',
#     'sub_off': '8',
#     'yellow': '7',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': "319'",
#     'minutes_played': "2.236'"},
#    {'season': '15/16',
#     'competition': 'Coupe de la Ligue',
#     'in_squad': '1',
#     'appearances': '1',
#     'pointspermatch': '0,00',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': '-',
#     'minutes_played': "90'"},
#    {'season': '15/16',
#     'competition': 'Champions League Qualifying',
#     'in_squad': '3',
#     'appearances': '2',
#     'pointspermatch': '1.50',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '1',
#     'yellow': '1',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': '-',
#     'minutes_played': "168'"},
#    {'season': '14/15',
#     'competition': 'Champions League',
#     'in_squad': '10',
#     'appearances': '7',
#     'pointspermatch': '1.57',
#     'goals': '-',
#     'assists': '1',
#     'owngoals': '-',
#     'sub_on': '6',
#     'sub_off': '-',
#     'yellow': '1',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': '-',
#     'minutes_played': "196'"},
#    {'season': '14/15',
#     'competition': 'Coupe de la Ligue',
#     'in_squad': '3',
#     'appearances': '3',
#     'pointspermatch': '2.00',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': '-',
#     'minutes_played': "330'"},
#    {'season': '13/14',
#     'competition': 'Liga Pro',
#     'in_squad': '38',
#     'appearances': '38',
#     'pointspermatch': '1.61',
#     'goals': '7',
#     'assists': '7',
#     'owngoals': '-',
#     'sub_on': '5',
#     'sub_off': '10',
#     'yellow': '4',
#     'secondyellow': '1',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': "428'",
#     'minutes_played': "2.993'"},
#    {'season': '13/14',
#     'competition': 'Taça de Portugal Placard',
#     'in_squad': '1',
#     'appearances': '1',
#     'pointspermatch': '3.00',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '1',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': '-',
#     'minutes_played': "10'"}],
#   'playertransfers': [{'season': '17/18',
#     'date': 'Jul 1, 2017',
#     'from_club': 'Monaco',
#     'to_club': 'Man City',
#     'value': '£36.00m',
#     'price': '£45.00m'},
#    {'season': '14/15',
#     'date': 'Jan 20, 2015',
#     'from_club': 'Benfica',
#     'to_club': 'Monaco',
#     'value': '£3.15m',
#     'price': '£14.18m'},
#    {'season': '14/15',
#     'date': 'Jan 19, 2015',
#     'from_club': 'Monaco',
#     'to_club': 'Benfica',
#     'value': '£3.15m',
#     'price': 'End of loan'},
#    {'season': '14/15',
#     'date': 'Aug 7, 2014',
#     'from_club': 'Benfica',
#     'to_club': 'Monaco',
#     'value': '£2.25m',
#     'price': 'Loan'},
#    {'season': '14/15',
#     'date': 'Jul 1, 2014',
#     'from_club': 'Benfica B',
#     'to_club': 'Benfica',
#     'value': '£2.25m',
#     'price': '-'},
#    {'season': '13/14',
#     'date': 'Jul 1, 2013',
#     'from_club': 'Benfica U19',
#     'to_club': 'Benfica B',
#     'value': '-',
#     'price': '-'},
#    {'season': '11/12',
#     'date': 'Jul 1, 2011',
#     'from_club': 'Benfica U17',
#     'to_club': 'Benfica U19',
#     'value': '-',
#     'price': '-'},
#    {'season': '09/10',
#     'date': 'Jul 1, 2009',
#     'from_club': 'Benfica U15',
#     'to_club': 'Benfica U17',
#     'value': '-',
#     'price': '-'},
#    {'season': '07/08',
#     'date': 'Jul 1, 2007',
#     'from_club': 'SL Benfica Yout',
#     'to_club': 'Benfica U15',
#     'value': '-',
#     'price': '-'}]},
#  {'kit': '9',
#   'name': 'Gabriel Jesus',
#   'genposition': 'Forward',
#   'specposition': 'Centre-Forward',
#   'dateofbirth': 'Apr 3, 1997 (23)',
#   'nationality': 'Brazil',
#   'height': '1,75 m',
#   'foot': 'right',
#   'joined': 'Jan 1, 2017',
#   'lastclub': 'Sociedade Esportiva Palmeiras',
#   'contract': '30.06.2023',
#   'playerurl': 'https://www.transfermarkt.co.uk/gabriel-jesus/profil/spieler/363205',
#   'marketvaluedata': {'date': ['May 31, 2015',
#     'Sep 11, 2015',
#     'Dec 15, 2015',
#     'May 27, 2016',
#     'Jul 23, 2016',
#     'Feb 20, 2017',
#     'Jun 28, 2017',
#     'Oct 23, 2017',
#     'Jan 2, 2018',
#     'May 28, 2018',
#     'Dec 19, 2018',
#     'Jun 13, 2019',
#     'Dec 10, 2019',
#     'Apr 8, 2020'],
#    'market_value': ['675000',
#     '1800000',
#     '3600000',
#     '7200000',
#     '14400000',
#     '22500000',
#     '27000000',
#     '40500000',
#     '63000000',
#     '72000000',
#     '63000000',
#     '63000000',
#     '63000000',
#     '50400000']},
#   'performancestats': [{'season': '19/20',
#     'competition': 'Premier League',
#     'in_squad': '25',
#     'appearances': '24',
#     'pointspermatch': '2.00',
#     'goals': '10',
#     'assists': '5',
#     'owngoals': '-',
#     'sub_on': '11',
#     'sub_off': '4',
#     'yellow': '2',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': "134'",
#     'minutes_played': "1.336'"},
#    {'season': '19/20',
#     'competition': 'EFL Cup',
#     'in_squad': '6',
#     'appearances': '6',
#     'pointspermatch': '2.50',
#     'goals': '1',
#     'assists': '1',
#     'owngoals': '-',
#     'sub_on': '4',
#     'sub_off': '1',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': "221'",
#     'minutes_played': "221'"},
#    {'season': '19/20',
#     'competition': 'Community Shield',
#     'in_squad': '1',
#     'appearances': '1',
#     'pointspermatch': '3.00',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '1',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': '-',
#     'minutes_played': "107'"},
#    {'season': '18/19',
#     'competition': 'Premier League',
#     'in_squad': '36',
#     'appearances': '29',
#     'pointspermatch': '2.55',
#     'goals': '7',
#     'assists': '3',
#     'owngoals': '-',
#     'sub_on': '21',
#     'sub_off': '4',
#     'yellow': '1',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '1',
#     'minutes_per_goal': "146'",
#     'minutes_played': "1.019'"},
#    {'season': '18/19',
#     'competition': 'EFL Cup',
#     'in_squad': '5',
#     'appearances': '5',
#     'pointspermatch': '3.00',
#     'goals': '5',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '2',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': "62'",
#     'minutes_played': "311'"},
#    {'season': '17/18',
#     'competition': 'Premier League',
#     'in_squad': '32',
#     'appearances': '29',
#     'pointspermatch': '2.69',
#     'goals': '13',
#     'assists': '4',
#     'owngoals': '-',
#     'sub_on': '10',
#     'sub_off': '14',
#     'yellow': '6',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': "129'",
#     'minutes_played': "1.671'"},
#    {'season': '17/18',
#     'competition': 'EFL Cup',
#     'in_squad': '4',
#     'appearances': '4',
#     'pointspermatch': '3.00',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '1',
#     'sub_off': '1',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': '-',
#     'minutes_played': "305'"},
#    {'season': '16/17',
#     'competition': 'FA Cup',
#     'in_squad': '1',
#     'appearances': '1',
#     'pointspermatch': '3.00',
#     'goals': '-',
#     'assists': '1',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': '-',
#     'minutes_played': "90'"},
#    {'season': '2016',
#     'competition': 'Libertadores',
#     'in_squad': '5',
#     'appearances': '5',
#     'pointspermatch': '1.00',
#     'goals': '4',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '2',
#     'sub_off': '-',
#     'yellow': '1',
#     'secondyellow': '-',
#     'red': '1',
#     'penalty': '-',
#     'minutes_per_goal': "85'",
#     'minutes_played': "341'"},
#    {'season': '19/20',
#     'competition': 'FA Cup',
#     'in_squad': '3',
#     'appearances': '2',
#     'pointspermatch': '3.00',
#     'goals': '2',
#     'assists': '1',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': "90'",
#     'minutes_played': "180'"},
#    {'season': '19/20',
#     'competition': 'Champions League',
#     'in_squad': '7',
#     'appearances': '6',
#     'pointspermatch': '2.33',
#     'goals': '5',
#     'assists': '2',
#     'owngoals': '-',
#     'sub_on': '1',
#     'sub_off': '2',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': "82'",
#     'minutes_played': "410'"},
#    {'season': '18/19',
#     'competition': 'FA Cup',
#     'in_squad': '6',
#     'appearances': '6',
#     'pointspermatch': '3.00',
#     'goals': '5',
#     'assists': '3',
#     'owngoals': '-',
#     'sub_on': '-',
#     'sub_off': '1',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': "105'",
#     'minutes_played': "525'"},
#    {'season': '18/19',
#     'competition': 'Champions League',
#     'in_squad': '8',
#     'appearances': '6',
#     'pointspermatch': '2.00',
#     'goals': '4',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '2',
#     'sub_off': '2',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '2',
#     'minutes_per_goal': "94'",
#     'minutes_played': "376'"},
#    {'season': '18/19',
#     'competition': 'Community Shield',
#     'in_squad': '1',
#     'appearances': '1',
#     'pointspermatch': '3.00',
#     'goals': '-',
#     'assists': '-',
#     'owngoals': '-',
#     'sub_on': '1',
#     'sub_off': '-',
#     'yellow': '-',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': '-',
#     'minutes_played': "22'"},
#    {'season': '17/18',
#     'competition': 'Champions League',
#     'in_squad': '9',
#     'appearances': '9',
#     'pointspermatch': '1.67',
#     'goals': '4',
#     'assists': '1',
#     'owngoals': '-',
#     'sub_on': '2',
#     'sub_off': '2',
#     'yellow': '2',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': "155'",
#     'minutes_played': "618'"},
#    {'season': '16/17',
#     'competition': 'Premier League',
#     'in_squad': '10',
#     'appearances': '10',
#     'pointspermatch': '2.40',
#     'goals': '7',
#     'assists': '4',
#     'owngoals': '-',
#     'sub_on': '2',
#     'sub_off': '3',
#     'yellow': '2',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '1',
#     'minutes_per_goal': "93'",
#     'minutes_played': "651'"},
#    {'season': '2016',
#     'competition': 'Série A',
#     'in_squad': '27',
#     'appearances': '27',
#     'pointspermatch': '2.19',
#     'goals': '13',
#     'assists': '4',
#     'owngoals': '-',
#     'sub_on': '1',
#     'sub_off': '4',
#     'yellow': '11',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': "178'",
#     'minutes_played': "2.319'"},
#    {'season': '2015',
#     'competition': 'Série A',
#     'in_squad': '28',
#     'appearances': '20',
#     'pointspermatch': '1.30',
#     'goals': '4',
#     'assists': '2',
#     'owngoals': '-',
#     'sub_on': '8',
#     'sub_off': '1',
#     'yellow': '5',
#     'secondyellow': '-',
#     'red': '-',
#     'penalty': '-',
#     'minutes_per_goal': "326'",
#     'minutes_played': "1.302'"}],
#   'playertransfers': [{'season': '16/17',
#     'date': 'Jan 1, 2017',
#     'from_club': 'Palmeiras',
#     'to_club': 'Man City',
#     'value': '£14.40m',
#     'price': '£28.80m'},
#    {'season': '14/15',
#     'date': 'Jan 1, 2015',
#     'from_club': 'Palmeiras U17',
#     'to_club': 'Palmeiras',
#     'value': '-',
#     'price': '-'}]}]

# %% [markdown]
# ## Google Search Data

# %%
# Not written yet
# Google search results
# https://www.google.com/search?q=lionel+messi
